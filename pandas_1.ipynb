# %% [markdown]
# <a href="https://colab.research.google.com/github/SeishiroInoue/diveintocode_machine_learning/blob/main/pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 問題1

import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
X = pd.DataFrame(iris.data, columns=["sepal_length", "sepal_width", "petal_length", "petal_width"])
Y = pd.DataFrame(iris.target, columns=["Species"])

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
Y
# Out:
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %%
# 問題2

df = pd.concat([X, Y], axis=1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
# 問題3

"""
先頭から4番目までのサンプルを表示させ、各特徴量がどういったものかを見る。（数値データか文字データかなど）
"""
df.head(4)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  Species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0

# %%
"""
ラベルごとのサンプル数の合計を出力する。
"""
df.sum()
# Out:
# sepal_length    876.5
# sepal_width     458.6
# petal_length    563.7
# petal_width     179.9
# Species         150.0
# dtype: float64

# %%
"""
特徴量に欠損値があるかを確認する。
"""
df.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
"""
特徴量の平均値と標準偏差、四分位数を一度に表示させる。
"""
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width     Species
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.057333      3.758000     1.199333    1.000000
# std        0.828066     0.435866      1.765298     0.762238    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.400000      6.900000     2.500000    2.000000

# %%
# 問題4

"""
Iris setosa
"""
茎は枝分かれしており、高さは非常に変化し 、高さは10cm(5インチ)から1m(3フィート)の範囲。
大きな植物は、葉の高さを超えて成長する可能性がある。
丸みを帯びた茎は、直径1.5〜9 cmで、1〜3本の枝がある。

"""
Iris virgicolor
"""
高さ10〜80 cm(4〜31インチ)の草本多年生植物。
厚い、忍び寄る根茎から大きな塊を形成する傾向がある。
翼のない直立した茎には、通常、幅が1 cm(1⁄2インチ)を超える基部の葉がある。

"""
Iris virginica
"""
2〜4枚の直立またはアーチ状の明るい緑色の槍形の葉があり、基部で1つの平面に平らになっている。
葉は1–3 cm (1⁄2 – 1+幅は1⁄4インチ)で、 花の茎よりも長い場合がある。
多肉質の根(直径1–2 cmまたは1⁄2 – 3⁄4) は、地下に広がる根茎。

# %%
# 問題5

"""
sepal_widthの列を2つの異なる方法で抽出する
"""
df["sepal_length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
"""
50番目から99番目までのデータを抽出する
"""
df[50:100]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  Species
# 50           7.0          3.2           4.7          1.4        1
# 51           6.4          3.2           4.5          1.5        1
# 52           6.9          3.1           4.9          1.5        1
# 53           5.5          2.3           4.0          1.3        1
# 54           6.5          2.8           4.6          1.5        1
# 55           5.7          2.8           4.5          1.3        1
# 56           6.3          3.3           4.7          1.6        1
# 57           4.9          2.4           3.3          1.0        1
# 58           6.6          2.9           4.6          1.3        1
# 59           5.2          2.7           3.9          1.4        1
# 60           5.0          2.0           3.5          1.0        1
# 61           5.9          3.0           4.2          1.5        1
# 62           6.0          2.2           4.0          1.0        1
# 63           6.1          2.9           4.7          1.4        1
# 64           5.6          2.9           3.6          1.3        1
# 65           6.7          3.1           4.4          1.4        1
# 66           5.6          3.0           4.5          1.5        1
# 67           5.8          2.7           4.1          1.0        1
# 68           6.2          2.2           4.5          1.5        1
# 69           5.6          2.5           3.9          1.1        1
# 70           5.9          3.2           4.8          1.8        1
# 71           6.1          2.8           4.0          1.3        1
# 72           6.3          2.5           4.9          1.5        1
# 73           6.1          2.8           4.7          1.2        1
# 74           6.4          2.9           4.3          1.3        1
# 75           6.6          3.0           4.4          1.4        1
# 76           6.8          2.8           4.8          1.4        1
# 77           6.7          3.0           5.0          1.7        1
# 78           6.0          2.9           4.5          1.5        1
# 79           5.7          2.6           3.5          1.0        1
# 80           5.5          2.4           3.8          1.1        1
# 81           5.5          2.4           3.7          1.0        1
# 82           5.8          2.7           3.9          1.2        1
# 83           6.0          2.7           5.1          1.6        1
# 84           5.4          3.0           4.5          1.5        1
# 85           6.0          3.4           4.5          1.6        1
# 86           6.7          3.1           4.7          1.5        1
# 87           6.3          2.3           4.4          1.3        1
# 88           5.6          3.0           4.1          1.3        1
# 89           5.5          2.5           4.0          1.3        1
# 90           5.5          2.6           4.4          1.2        1
# 91           6.1          3.0           4.6          1.4        1
# 92           5.8          2.6           4.0          1.2        1
# 93           5.0          2.3           3.3          1.0        1
# 94           5.6          2.7           4.2          1.3        1
# 95           5.7          3.0           4.2          1.2        1
# 96           5.7          2.9           4.2          1.3        1
# 97           6.2          2.9           4.3          1.3        1
# 98           5.1          2.5           3.0          1.1        1
# 99           5.7          2.8           4.1          1.3        1

# %%
"""
petal_lengthの列の50番目から99番目までのデータを抽出する
"""
df.loc[50:99, ["petal_length"]]
# Out:
#     petal_length
# 50           4.7
# 51           4.5
# 52           4.9
# 53           4.0
# 54           4.6
# 55           4.5
# 56           4.7
# 57           3.3
# 58           4.6
# 59           3.9
# 60           3.5
# 61           4.2
# 62           4.0
# 63           4.7
# 64           3.6
# 65           4.4
# 66           4.5
# 67           4.1
# 68           4.5
# 69           3.9
# 70           4.8
# 71           4.0
# 72           4.9
# 73           4.7
# 74           4.3
# 75           4.4
# 76           4.8
# 77           5.0
# 78           4.5
# 79           3.5
# 80           3.8
# 81           3.7
# 82           3.9
# 83           5.1
# 84           4.5
# 85           4.5
# 86           4.7
# 87           4.4
# 88           4.1
# 89           4.0
# 90           4.4
# 91           4.6
# 92           4.0
# 93           3.3
# 94           4.2
# 95           4.2
# 96           4.2
# 97           4.3
# 98           3.0
# 99           4.1

# %%
"""
petal_widthの値が0.2のデータを抽出する
"""
df[df.petal_width == 0.2]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  Species
# 0            5.1          3.5           1.4          0.2        0
# 1            4.9          3.0           1.4          0.2        0
# 2            4.7          3.2           1.3          0.2        0
# 3            4.6          3.1           1.5          0.2        0
# 4            5.0          3.6           1.4          0.2        0
# 7            5.0          3.4           1.5          0.2        0
# 8            4.4          2.9           1.4          0.2        0
# 10           5.4          3.7           1.5          0.2        0
# 11           4.8          3.4           1.6          0.2        0
# 14           5.8          4.0           1.2          0.2        0
# 20           5.4          3.4           1.7          0.2        0
# 22           4.6          3.6           1.0          0.2        0
# 24           4.8          3.4           1.9          0.2        0
# 25           5.0          3.0           1.6          0.2        0
# 27           5.2          3.5           1.5          0.2        0
# 28           5.2          3.4           1.4          0.2        0
# 29           4.7          3.2           1.6          0.2        0
# 30           4.8          3.1           1.6          0.2        0
# 33           5.5          4.2           1.4          0.2        0
# 34           4.9          3.1           1.5          0.2        0
# 35           5.0          3.2           1.2          0.2        0
# 36           5.5          3.5           1.3          0.2        0
# 38           4.4          3.0           1.3          0.2        0
# 39           5.1          3.4           1.5          0.2        0
# 42           4.4          3.2           1.3          0.2        0
# 46           5.1          3.8           1.6          0.2        0
# 47           4.6          3.2           1.4          0.2        0
# 48           5.3          3.7           1.5          0.2        0
# 49           5.0          3.3           1.4          0.2        0

# %%
"""
.locや.ilocの違い
"""
locはラベルを指定し、ilocはインデックスを指定する。

# %%
# 問題6

"""
ラベルごとのサンプル数を円グラフにする（パーセンテージまで表示する）
"""

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.pie(df['Species'].value_counts(),
        labels=iris['target_names'], autopct='%d%%',
        startangle=90, counterclock=False)
plt.show()

# %%
"""
特徴量を一つずつ選び、箱ひげ図を使ってラベルごとのデータの分布を可視化する
"""
species_0 = df[df['Species']==0].iloc[:, 0:4].reset_index(drop=True)
species_1 = df[df['Species']==1].iloc[:, 0:4].reset_index(drop=True)
species_2 = df[df['Species']==2].iloc[:, 0:4].reset_index(drop=True)

species_list = []
plt.figure(figsize=(8, 8))

for i in range(len(df.columns.values)-1):
  species_list_i = []
  species_list_i.append(species_0.iloc[:, i])
  species_list_i.append(species_1.iloc[:, i])
  species_list_i.append(species_2.iloc[:, i])
  species_list.append(species_list_i)

  plt.subplot(2, 2, i+1)
  plt.boxplot(species_list[i],
                    flierprops={'markerfacecolor':'r', 'marker':'s'},
                    boxprops={'color':'b'}, patch_artist=True,
                    labels=iris['target_names'])
  plt.title(df.columns.values[i])
  plt.ylabel(df.columns.values[i])
  plt.xlabel(df.columns.values[-1])

plt.tight_layout()
plt.show()

# %%
"""
特徴量を一つずつ選び、バイオリン図を使ってラベルごとのデータの分布を可視化する
"""
plt.figure(figsize=(8, 8))

for i in range(len(df.columns.values)-1):
  plt.subplot(2, 2, i+1)
  plt.violinplot(species_list[i], showmedians=True)
  plt.title(df.columns.values[i])
  plt.ylabel(df.columns.values[i])
  plt.xticks([1, 2, 3],iris['target_names'])

plt.tight_layout()
plt.show()

# %%
# 問題7

"""
４つの特徴量から２つ選ぶようなすべての組み合わせ（６つ）の散布図を種類ごとに色分けして作る。
"""
count = 0
for i in range(4):
  for j in range(4):
    if count == 6:
      break
    else:    
      if i == j:
        pass
      else:
        count +=1
        sns.scatterplot(x=df.iloc[:,i], y=df.iloc[:,j],hue=df['Species'],data=iris)
        plt.show()

# %%
"""
すべての特徴量の組み合わせを一度に表示させた、散布図行列を作る。
"""
sns.pairplot(df, hue='Species')
plt.show()

# %%
"""
４つの特徴量に関する相関係数行列を作る
"""
corr_mat = df.iloc[:,:4].corr()
corr_mat
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
"""
相関係数行列のヒートマップを作る(１つ)
"""
sns.heatmap(corr_mat)
plt.show()

# %%
# 問題8

petal_lengthとpetal_widthには正の相関がある。
