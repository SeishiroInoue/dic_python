# %% [markdown]
# <a href="https://colab.research.google.com/github/SeishiroInoue/dic_python/blob/main/Matplotlib_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 紙を1回折った時の厚さを計算するコード

THICKNESS = 0.00008

folded_thickness = THICKNESS * 2 ** 43

print("厚さ： {}メートル".format(folded_thickness))
# Out:
# 厚さ： 703687441.77664メートル

# %%
# メートルをキロメートルに変換して小数点以下2桁で表示する
print("厚さ： {:.2f}万キロメートル".format(folded_thickness / 10000000))
# Out:
# 厚さ： 70.37万キロメートル

# %%
folded_thickness = THICKNESS
for i in range(43):
  folded_thickness = folded_thickness * 2

print("厚さ： {}メートル".format(folded_thickness))
# Out:
# 厚さ： 703687441.77664メートル

# %%
import time
start = time.time()
a = 2 ** 10
b = 2 ** 100
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# time : 9.131431579589844e-05[s]

# %%
# %%timeit

a = 2 ** 10
b = 2 ** 100
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# time : 7.512575626373291[s]
# time : 7.512618064880371[s]
# time : 7.512646198272705[s]
# time : 7.512673616409302[s]
# time : 7.51270055770874[s]
# time : 7.5127272605896[s]
# time : 7.512754201889038[s]
# time : 7.512795925140381[s]
# time : 7.512842416763306[s]
# time : 7.512868642807007[s]
# time : 7.512896776199341[s]
# time : 7.512924909591675[s]
# time : 7.512953042984009[s]
# time : 7.512980699539185[s]
# time : 7.51300835609436[s]
# time : 7.513034343719482[s]
# time : 7.513062477111816[s]
# time : 7.51309061050415[s]
# time : 7.513118505477905[s]
# time : 7.513146638870239[s]
# time : 7.513174772262573[s]
# time : 7.513203859329224[s]
# time : 7.513232469558716[s]
# time : 7.513260364532471[s]
# time : 7.513288974761963[s]
# time : 7.513317108154297[s]
# time : 7.513345003128052[s]
# time : 7.513373136520386[s]
# time : 7.513401031494141[s]
# time : 7.513428688049316[s]
# time : 7.513457536697388[s]
# time : 7.5134851932525635[s]
# ...

# %%
THICKNESS = 0.00008
folded_thickness = []
folded_thickness.append(THICKNESS)
for i in range(43):
  folded_thickness.append(THICKNESS * 2 ** i)
print(len(folded_thickness))
# Out:
# 44

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# グラフを表示する。タイトルと軸ラベル名付き。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(folded_thickness)  # 「リスト名」のところにリストの変数名を入れる
plt.show()

# %%
# 緑色の折れ線グラフを表示する。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(folded_thickness, color='green')
plt.show()

# 太い折れ線グラフを表示する。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(folded_thickness, linewidth=10)
plt.show()

# 点線の折れ線グラフを表示する。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(folded_thickness, linestyle=':')
plt.show()
